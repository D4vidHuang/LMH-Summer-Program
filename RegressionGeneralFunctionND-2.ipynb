# %%
#Linear Regression for general functions
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

pi=math.pi

fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=np.cos(2*pi*X1)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# /var/folders/2n/j0d_6pdj23bbvfpk9vjvjc2h0000gn/T/ipykernel_2703/2812389265.py:11: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
X = []
nb = 8
X1_tilda = np.reshape(X1, (X1.shape[0]*X1.shape[1]))
X2_tilda = np.reshape(X2, (X2.shape[0]*X2.shape[1]))
Y_tilda = np.reshape(Y, (Y.shape[0]*Y.shape[1]))

X1_tilda = X1_tilda[:, np.newaxis, np.newaxis]
X2_tilda = X2_tilda[ :, np.newaxis, np.newaxis]
I = np.arange(nb+1)
I = I[np.newaxis, :, np.newaxis]

J = np.arange(nb+1)
J = J[np.newaxis,  np.newaxis,:]

X = X1_tilda**I * X2_tilda**J
print(X.shape)
X = np.reshape(X, (X.shape[0], X.shape[1]*X.shape[2]))
print(X.shape)
# 
#for i in range(nb+1):
#  for j in range(nb+1):
#    X.append(X1_tilda**i * X2_tilda**j)


#X = np.array(X).T
# print(X.shape)
w = np.linalg.inv(X.T@X)@(X.T@Y_tilda)

Yhat = np.reshape(X@w, (Y.shape[0],Y.shape[1]))

fig = plt.figure()
ax = fig.gca(projection='3d')



surf = ax.plot_surface(X1, X2, Yhat, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# (10000, 9, 9)
# (10000, 81)
# /var/folders/2n/j0d_6pdj23bbvfpk9vjvjc2h0000gn/T/ipykernel_2703/4244217602.py:32: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=(X1**2)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# /var/folders/2n/j0d_6pdj23bbvfpk9vjvjc2h0000gn/T/ipykernel_3529/2026081933.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
X = []
nb = 7
X1_tilda = np.reshape(X1, (X1.shape[0]*X1.shape[1]))
X2_tilda = np.reshape(X2, (X2.shape[0]*X2.shape[1]))
Y_tilda = np.reshape(Y, (Y.shape[0]*Y.shape[1]))
for i in range(nb+1):
  for j in range(nb+1):
    X.append(X1_tilda**i * X2_tilda**j)


X = np.array(X).T
print(X.shape)
w = np.linalg.inv(X.T@X)@(X.T@Y_tilda)

Yhat = np.reshape(X@w, (Y.shape[0],Y.shape[1]))

fig = plt.figure()
ax = fig.gca(projection='3d')



surf = ax.plot_surface(X1, X2, Yhat, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# (10000, 64)
# /var/folders/2n/j0d_6pdj23bbvfpk9vjvjc2h0000gn/T/ipykernel_3529/1012619113.py:18: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=(X1>0)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# %%
X = []
nb = 7
X1_tilda = np.reshape(X1, (X1.shape[0]*X1.shape[1]))
X2_tilda = np.reshape(X2, (X2.shape[0]*X2.shape[1]))
Y_tilda = np.reshape(Y, (Y.shape[0]*Y.shape[1]))
for i in range(nb+1):
  for j in range(nb+1):
    X.append(X1_tilda**i * X2_tilda**j)


X = np.array(X).T
print(X.shape)
w = np.linalg.inv(X.T@X)@(X.T@Y_tilda)

Yhat = np.reshape(X@w, (Y.shape[0],Y.shape[1]))

fig = plt.figure()
ax = fig.gca(projection='3d')



surf = ax.plot_surface(X1, X2, Yhat, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# (10000, 64)

# %%
#[x^0, x^1, x^2..x^M]
#yhat = X@w
#w = (X.T @ X)^-1 @ (X.T @ y)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
x1=np.linspace(-1,1,100)
x2=np.linspace(-1,1,100)
[X1,X2]=np.meshgrid(x1,x2)

Y=np.exp(X1**5)*np.sin(2*pi*1*X2)+0.1*np.random.randn(X1.shape[0],X1.shape[1])


surf = ax.plot_surface(X1, X2, Y, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# %%
X = []
nb = 7
X1_tilda = np.reshape(X1, (X1.shape[0]*X1.shape[1]))
X2_tilda = np.reshape(X2, (X2.shape[0]*X2.shape[1]))
Y_tilda = np.reshape(Y, (Y.shape[0]*Y.shape[1]))
for i in range(nb+1):
  for j in range(nb+1):
    X.append(X1_tilda**i * X2_tilda**j)


X = np.array(X).T
print(X.shape)
w = np.linalg.inv(X.T@X)@(X.T@Y_tilda)

Yhat = np.reshape(X@w, (Y.shape[0],Y.shape[1]))

fig = plt.figure()
ax = fig.gca(projection='3d')



surf = ax.plot_surface(X1, X2, Yhat, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# (10000, 64)

# %%
#THIS IS A BONUS QUESTION
#DCT regression for images

import scipy.fftpack as sf

img = np.zeros((28,28))
img[10:15, 10:15]=1

img1 = sf.dct(img)
#DCT conpressed img
plt.figure()
plt.imshow(img1)
#IDCT img
plt.figure()
plt.imshow(sf.idct(img1))
